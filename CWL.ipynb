# %%
import pandas as pd 

CWL_champs_data = pd.read_csv('CWL_Champs2018.txt')

CWL_champs_data.to_csv('CWL_Champs.csv', index=False)

# %%
CWL_champs_data.head(10)
# Out:
#                                match id        series id  \
# 0  6017262a-bb57-5f95-b484-3ed560496ab6  champs-pool-A-3
# 1  6017262a-bb57-5f95-b484-3ed560496ab6  champs-pool-A-3
# 2  6017262a-bb57-5f95-b484-3ed560496ab6  champs-pool-A-3
# 3  6017262a-bb57-5f95-b484-3ed560496ab6  champs-pool-A-3
# 4  6017262a-bb57-5f95-b484-3ed560496ab6  champs-pool-A-3
# 5  6017262a-bb57-5f95-b484-3ed560496ab6  champs-pool-A-3
# 6  6017262a-bb57-5f95-b484-3ed560496ab6  champs-pool-A-3
# 7  6017262a-bb57-5f95-b484-3ed560496ab6  champs-pool-A-3
# 8  021b1342-3006-5416-90fa-af3ba35a8843  champs-pool-A-2
# 9  021b1342-3006-5416-90fa-af3ba35a8843  champs-pool-A-2
#
#                   end time  duration (s)       mode                   map  \
# 0  2018-08-15 16:12:12 UTC           552  Hardpoint              Valkyrie
# 1  2018-08-15 16:12:12 UTC           552  Hardpoint              Valkyrie
# 2  2018-08-15 16:12:12 UTC           552  Hardpoint              Valkyrie
# ...

# %%
CWL_champs_data.columns
columns_to_drop = ['snd firstbloods', 'snd firstdeaths',
'snd survives', 'bomb pickups', 'bomb plants', 'bomb defuses',
'bomb sneak defuses', 'snd 1-kill round', 'snd 2-kill round',
'snd 3-kill round', 'snd 4-kill round', 'ctf captures', 'ctf returns',
'ctf pickups', 'ctf defends', 'ctf kill carriers',
'ctf flag carry time (s)', '2-piece', '3-piece', '4-piece', '4-streak',
'5-streak', '6-streak', '7-streak', '8+-streak', 'scorestreaks earned',
'scorestreaks used', 'scorestreaks deployed', 'scorestreaks kills',
'scorestreaks assists',  'hill captures',
'hill defends','num lives', 'time alive (s)',
'avg time per life (s)', 'fave division',
'fave training', 'fave scorestreaks']
CWL_champs_data_cop = CWL_champs_data.copy()
CWL_champs_data_cop = CWL_champs_data_cop.drop(columns=columns_to_drop)
CWL_champs_data_cop.head()
# Out:
#                                match id        series id  \
# 0  6017262a-bb57-5f95-b484-3ed560496ab6  champs-pool-A-3
# 1  6017262a-bb57-5f95-b484-3ed560496ab6  champs-pool-A-3
# 2  6017262a-bb57-5f95-b484-3ed560496ab6  champs-pool-A-3
# 3  6017262a-bb57-5f95-b484-3ed560496ab6  champs-pool-A-3
# 4  6017262a-bb57-5f95-b484-3ed560496ab6  champs-pool-A-3
#
#                   end time  duration (s)       mode       map      team  \
# 0  2018-08-15 16:12:12 UTC           552  Hardpoint  Valkyrie   Epsilon
# 1  2018-08-15 16:12:12 UTC           552  Hardpoint  Valkyrie   Epsilon
# 2  2018-08-15 16:12:12 UTC           552  Hardpoint  Valkyrie   Epsilon
# 3  2018-08-15 16:12:12 UTC           552  Hardpoint  Valkyrie   Epsilon
# 4  2018-08-15 16:12:12 UTC           552  Hardpoint  Valkyrie  Heretics
#
#    player win?  score  ...  suicides  team kills  team deaths  \
# 0   Dqvee    L    200  ...         0           0            0
# ...

# %%
CWL_champs_data_cop.to_csv('CWL_Champs_tab.csv')
